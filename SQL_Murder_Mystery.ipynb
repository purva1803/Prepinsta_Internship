# %% [markdown]
# <a href="https://colab.research.google.com/github/purva1803/Prepinsta_Internship/blob/main/SQL_Murder_Mystery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sqlite3 as sql

# %% [markdown]
# **Import Database**

# %%
conn = sql.connect("/content/sql-murder-mystery.db")

# %%
conn

# %% [markdown]
# **Retrieve Crime Scene Report**

# %%
query_1 = """
SELECT *
FROM crime_scene_report
WHERE city = "SQL City"
ORDER BY date;
"""
pd.set_option('display.max_colwidth', None)
pd.read_sql_query(query_1, conn)
# Out:
#        date     type  \
# 0  20170712    theft
# 1  20170820    arson
# 2  20171110  robbery
# 3  20180103  bribery
# 4  20180115  assault
# 5  20180115  assault
# 6  20180115   murder
# 7  20180215   murder
# 8  20180215   murder
#
#                                                                                                                                                                                                                                                               description  \
# 0              A lone hunter stalks the night, firing arrows into the Darkness.\n            There is no hiding, no escape. In the distance, the beast\n            falters, tethered to the void. The killing blow comes without\n            hesitation, without mercy.
# ...

# %% [markdown]
# **Witness Personal Details**

# %%
query_2 = """
SELECT * FROM person;

"""
pd.read_sql_query(query_2,conn)
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
query_3 = """
SELECT * FROM person
WHERE address_street_name = "Northwestern Dr"
ORDER BY address_number desc;
"""
pd.read_sql_query(query_3, conn)[:1]
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn
# 0  111564949

# %%
query_4 = """
SELECT *FROM person
WHERE name like '%Annabel%' AND address_street_name = "Franklin Ave";
"""
pd.read_sql_query(query_4, conn)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# **View Witness Interviews**

# %%
query_5 = """
SELECT *
FROM interview
WHERE person_id = 14887 OR person_id = 16371;
"""
pd.read_sql_query(query_5, conn)
# Out:
#    person_id  \
# 0      14887
# 1      16371
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# 1                                                                                                            I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# **Check Gym Database**

# %%
query_6 = """
SELECT * FROM get_fit_now_check_in
WHERE membership_id like "%48Z%" AND check_in_date = 20180109
order by check_in_date;
"""
pd.read_sql_query(query_6, conn)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z7A       20180109           1600            1730
# 1         48Z55       20180109           1530            1700

# %% [markdown]
# **Check Car Details**

# %%
query_7 = """
SELECT *
FROM drivers_license
WHERE plate_number like "%H42W%";
"""
pd.read_sql_query(query_7, conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number   car_make  \
# 0  183779   21      65      blue     blonde  female       H42W0X     Toyota
# 1  423327   30      70     brown      brown    male       0H42W2  Chevrolet
# 2  664760   21      71     black      black    male       4H42WR     Nissan
#
#   car_model
# 0     Prius
# 1  Spark LS
# 2    Altima

# %% [markdown]
# **Personal Details**

# %%
query_8 = """
SELECT *
FROM person
WHERE license_id = "183779" OR license_id = "423327";
"""
pd.read_sql_query(query_8, conn)
# Out:
#       id            name  license_id  address_number    address_street_name  \
# 0  67318   Jeremy Bowers      423327             530  Washington Pl, Apt 3A
# 1  78193  Maxine Whitely      183779             110                Fisk Rd
#
#          ssn
# 0  871539279
# 1  137882671

# %% [markdown]
# **Membership Status at the Gym**

# %%
query_9 = """
SELECT * FROM get_fit_now_member
WHERE person_id = "67318" OR person_id = "78193";
"""
pd.read_sql_query(query_9, conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# **Analyze and Draw Conclusions**

# %%
query_10 = """
SELECT * FROM interview
WHERE person_id = 67318;
"""
pd.read_sql_query(query_10, conn)
# Out:
#    person_id  \
# 0      67318
#
#                                                                                                                                                                                                                                            transcript
# 0  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %% [markdown]
# **Document FindingS**

# %%
query_11 = """
SELECT * FROM drivers_license
WHERE car_make = "Tesla" AND car_model = "Model S" AND
gender = "female" AND hair_color = "red";
"""
pd.read_sql_query(query_11, conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %%
query_12 = """
SELECT *
FROM person
WHERE license_id = "202298" OR license_id = "291182" OR license_id = "918773";
"""
pd.read_sql_query(query_12, conn)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %% [markdown]
# **checking the event SQL symphony concert**

# %%
query_13 = """
SELECT person_id, count(*), event_name
FROM facebook_event_checkin
GROUP BY person_id
having count(*) = 3 AND event_name = "SQL Symphony Concert" AND date like "%201712%";
"""
pd.read_sql_query(query_13, conn)
# Out:
#    person_id  count(*)            event_name
# 0      24556         3  SQL Symphony Concert
# 1      99716         3  SQL Symphony Concert

# %% [markdown]
# **Revealing Mastermind Behind Murder**

# %%
print("You've been chasing the mystery for weeks.")
print("Unexpectedly, the real villain is about to be revealed...")

# Pause for dramatic effect
input("Press Enter to continue...")

print("The lights dim as a figure emerges from the shadows.")
print("It's Miranda Priestly, the unsuspected mastermind!")

# Continue the story
print("Miranda: 'You thought you could outsmart me, but you were just a pawn in my game.'")
print("As Miranda reveals her sinister plans, you realize the depth of the conspiracy.")

# Conclude the story
print("In the final confrontation, justice is served, and the mystery is finally solved.")
print("The end.")
# Out:
# You've been chasing the mystery for weeks.
# Unexpectedly, the real villain is about to be revealed...
# Press Enter to continue...
# The lights dim as a figure emerges from the shadows.
# It's Miranda Priestly, the unsuspected mastermind!
# Miranda: 'You thought you could outsmart me, but you were just a pawn in my game.'
# As Miranda reveals her sinister plans, you realize the depth of the conspiracy.
# In the final confrontation, justice is served, and the mystery is finally solved.
# The end.
